# %% [markdown]
# # Phase 3: Exploratory Data Analysis (EDA)
#
# This notebook visualizes the spatial coverage and statistical profiles of the Kosovo datasets.
#
# ## 1. Setup & Loading

# %%
import sys
from pathlib import Path

# Add src to path
PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))

from src.loaders import load_hpd, load_nav_streets, load_vpd
from src.visualization.eda import plot_spatial_coverage, plot_distributions, calculate_overlap_stats
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Load Data
# *Note: VPD loading might take ~5-10 minutes due to large WKT parsing.*

# %%
print("Loading Nav Streets...")
nav_gdf = load_nav_streets()

print("Loading HPD (Probes)...")
hpd_gdf = load_hpd()

print("Loading VPD (this may take time)...")
vpd_gdf = load_vpd()

# %% [markdown]
# ## 3. Spatial Coverage Maps (Phase 3a)
# Visualizing where we have data vs. reference roads.

# %%
plot_spatial_coverage(vpd_gdf, hpd_gdf, nav_gdf)

# %% [markdown]
# ## 4. Statistical Distributions (Phase 3b)

# %%
plot_distributions(vpd_gdf, hpd_gdf, nav_gdf)

# %% [markdown]
# ## 5. Overlap Analysis
# Quantifying the "New Road" potential.

# %%
overlap = calculate_overlap_stats(vpd_gdf, nav_gdf, buffer_m=15.0)
print(overlap)
