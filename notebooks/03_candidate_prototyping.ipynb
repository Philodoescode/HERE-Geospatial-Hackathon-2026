# %% [markdown]
# # Phase 5C: Candidate Algorithm Prototyping
#
# This notebook prototypes and tests the 4 candidate algorithms for centerline generation:
# 1. **KDE + Skeletonization**
# 2. **DBSCAN Point Clustering**
# 3. **Trace Clustering (Hausdorff)**
# 4. **Incremental Graph Construction**
#
# Implementations are mirrored in `src.algorithms.candidates`.

# %%
import geopandas as gpd
from src.algorithms import (
    candidate_kde_skeleton,
    candidate_dbscan_polyline,
    candidate_trace_clustering,
    candidate_incremental_graph
)
from src.loaders.vpd_loader import load_vpd
from src.config import CRS
